# %% [markdown]
# # Test MATCHER

# %% [markdown]
# **Imports**

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'png'
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pkg_resources
from pymatcher import matcher

# %% [markdown]
# **Read reduced thymus F74 Data**

# %%
f74_rna = np.genfromtxt("/home/jovyan/my_data/F74_RNA_redDim.csv",delimiter=',')
f74_atac = np.genfromtxt("/home/jovyan/my_data/F74_ATAC_redDim.csv",delimiter=',')

f74_rna = f74_rna[1:,1:]
f74_atac = f74_atac[1:,1:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-03a53c25afa6> in <module>
# ----> 1 f74_rna = np.genfromtxt("/home/jovyan/my_data/F74_RNA_redDim.csv",delimiter=',')
#       2 f74_atac = np.genfromtxt("/home/jovyan/my_data/F74_ATAC_redDim.csv",delimiter=',')
#       3
#       4 f74_rna = f74_rna[1:,1:]
#       5 f74_atac = f74_atac[1:,1:]
#
# NameError: name 'np' is not defined

# %% [markdown]
# **Use MATCHER to Infer Pseudotime and Master Time**
#
# Try on subset of cells

# %%
# small_rna = f74_rna[0:1000,]
# small_atac = f74_atac[0:1000,]

# %%
X = [f74_rna,f74_atac]
m = matcher.MATCHER(X)
m.infer()
# Out:
# HBox(children=(VBox(children=(IntProgress(value=0, max=1000), HTML(value=''))), Box(children=(HTML(value=''),)…
# HBox(children=(VBox(children=(IntProgress(value=0, max=1000), HTML(value=''))), Box(children=(HTML(value=''),)…

# %%
m.learn_warp_function(1,reverse=False)

# %%
model0 = m.model[0]

# %%
model0
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: bayesian gplvm<br>
# <b>Objective</b>: 393226.61249892507<br>
# <b>Number of Parameters</b>: 14393<br>
# <b>Number of Optimization Parameters</b>: 14393<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  bayesian_gplvm.        </b></th><th><b>             value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  latent space.mean      </td><td class=tg-right>         (7190, 1)</td><td class=tg-center>           </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  latent space.variance  </td><td class=tg-right>         (7190, 1)</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  inducing inputs        </td><td class=tg-right>           (10, 1)</td><td class=tg-center>           </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  rbf.variance           </td><td class=tg-right> 2.969847513165725</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  rbf.lengthscale        </td><td class=tg-right>0.6112984506288767</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance</td><td class=tg-right>1.8792361673845073</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %% [markdown]
# **Plot Warping Functions**
#
# We can now examine the relationship between pseudotime and master time by plotting the warping functions inferred by MATCHER. The x-axis on each plot is pseudotime and the y-axis is master time.

# %%
ax = m.warp_functions[0].plot()
# Out:
#  /home/jovyan/.local/lib/python3.7/site-packages/matplotlib/figure.py:2369: UserWarning:This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
ax = m.warp_functions[1].plot()

# %% [markdown]
# **Write Inferred Pseudotime Values to File**

# %%
np.savetxt("/home/jovyan/models/test_RNA_pseudotime.csv",m.model[0].latent_space.mean,delimiter=",")
np.savetxt("/home/jovyan/models/test_ATAC_pseudotime.csv",m.model[1].latent_space.mean,delimiter=",")

# %% [markdown]
# **Write Inferred Master Time Values to File**

# %%
np.savetxt("/home/jovyan/models/test_RNA_master_time.csv",m.master_time[0],delimiter=",")
np.savetxt("/home/jovyan/models/test_ATAC_master_time.csv",m.master_time[1],delimiter=",")

# %% [markdown]
# **Inspect the Gaussian Process Mapping from Pseudotime to Gene Expression Space for the DNMT3B Gene**

# %%
m.plot_feature(0,10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-0e584dc5be8b> in <module>
# ----> 1 m.plot_feature(0,10)
#
# ~/my-conda-envs/emma_env/lib/python3.7/site-packages/pymatcher/matcher.py in plot_feature(self, model_ind, feature_ind)
#     306         """
#     307         fig = self.model[model_ind].plot_f(which_data_ycols=[feature_ind],plot_inducing=False)
# --> 308         fig.scatter(self.model[model_ind].latent_space.mean,self.X[model_ind][:,feature_ind],marker='x',c="black")
#     309
#     310     def plot_master_time(self,inds):
#
# AttributeError: 'dict' object has no attribute 'scatter'

# %% [markdown]
# **Use MATCHER to Infer Simultaneous Gene Expression and DNA Methylation Measurements**

# %%
corr_feat = m.infer_corresponding_features(0,1,np.array(range(0,34)),np.array(range(0,27)))
m.plot_corresponding_features(0,1,10,18)
plt.xlabel('DNMT3B Gene Expression')
plt.ylabel('DPPA3 Promoter Methylation')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     173     try:
# --> 174         rgba = _colors_full_map.cache[c, alpha]
#     175     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# TypeError: unhashable type: 'numpy.ndarray'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4231             try:  # Then is 'c' acceptable as PathCollection facecolors?
# -> 4232                 colors = mcolors.to_rgba_array(c)
#    4233                 n_elem = colors.shape[0]
#
# ~/.local/lib/python3.7/site-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     274     for i, cc in enumerate(c):
# --> 275         result[i] = to_rgba(cc, alpha)
#     276     return result
#
# ~/.local/lib/python3.7/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     175     except (KeyError, TypeError):  # Not in cache, or unhashable.
# --> 176         rgba = _to_rgba_no_colorcycle(c, alpha)
#     177         try:
#
# ~/.local/lib/python3.7/site-packages/matplotlib/colors.py in _to_rgba_no_colorcycle(c, alpha)
#     230     if len(c) not in [3, 4]:
# --> 231         raise ValueError("RGBA sequence should have length 3 or 4")
#     232     if len(c) == 3 and alpha is None:
#
# ValueError: RGBA sequence should have length 3 or 4
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-8fe667c309d0> in <module>
#       1 corr_feat = m.infer_corresponding_features(0,1,np.array(range(0,34)),np.array(range(0,27)))
# ----> 2 m.plot_corresponding_features(0,1,10,18)
#       3 plt.xlabel('DNMT3B Gene Expression')
#       4 plt.ylabel('DPPA3 Promoter Methylation')
#
# ~/MATCHER/pymatcher/matcher.py in plot_corresponding_features(self, model1, model2, ind1, ind2)
#     242         vals1 = self.X[model1][:,ind1]
#     243         vals2 = self.model[model2].predict(model2_internal)[0][:,ind2]
# --> 244         plt.scatter(vals1,vals2,c=t,cmap='hot')
#     245         cb = plt.colorbar()
#     246         cb.set_label('Master Time')
#
# ~/.local/lib/python3.7/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, data, **kwargs)
#    2860         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2861         verts=verts, edgecolors=edgecolors, **({"data": data} if data
# -> 2862         is not None else {}), **kwargs)
#    2863     sci(__ret)
#    2864     return __ret
#
# ~/.local/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/.local/lib/python3.7/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4243                         "acceptable for use with 'x' with size {xs}, "
#    4244                         "'y' with size {ys}."
# -> 4245                         .format(nc=n_elem, xs=x.size, ys=y.size)
#    4246                     )
#    4247                 # Both the mapping *and* the RGBA conversion failed: pretty
#
# ValueError: 'c' argument has 177 elements, which is not acceptable for use with 'x' with size 177, 'y' with size 177.

# %% [markdown]
# **Use MATCHER to Infer Correlation Between Gene Expression and DNA Methylation**

# %%
exp_met_corr = m.correlation(0,1,np.array(range(0,34)),np.array(range(0,27)),method="Spearman")
# Out:
#  /nas/longleaf/apps/anaconda/4.3.0/anaconda/lib/python3.6/site-packages/numpy/lib/function_base.py:2569: RuntimeWarning:invalid value encountered in true_divide
#  /nas/longleaf/apps/anaconda/4.3.0/anaconda/lib/python3.6/site-packages/numpy/lib/function_base.py:2570: RuntimeWarning:invalid value encountered in true_divide
#  /nas/longleaf/apps/anaconda/4.3.0/anaconda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:875: RuntimeWarning:invalid value encountered in greater
#  /nas/longleaf/apps/anaconda/4.3.0/anaconda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:875: RuntimeWarning:invalid value encountered in less
#  /nas/longleaf/apps/anaconda/4.3.0/anaconda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1814: RuntimeWarning:invalid value encountered in less_equal

# %% [markdown]
# **Infer Shared Master Time from Gene Expression and DNA Methylation**
#
# Adding a second level list to the MATCHER input tells MATCHER that we want to infer shared master time for the datasets in the second level list. Note that it is possible to infer shared master time for some datasets for which correspondences are known while also inferring master time for other data types where the correspondence is not known. For example, we could infer shared master time from sc-GEM data and a separate set of master time values for scATAC-seq data.

# %%
X = [[cheow_exp,cheow_met]]
m = matcher.MATCHER(X)
m.infer()

# %% [markdown]
# **Plot Warping Function for Shared Master Time**

# %%
ax = m.warp_functions[0].plot()
ax.legend(loc='best')
plt.title("Shared Master Time",fontsize=20)
# Out:
#  /nas/longleaf/apps/anaconda/4.3.0/anaconda/lib/python3.6/site-packages/matplotlib/figure.py:1742: UserWarning:This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
